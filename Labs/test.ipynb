# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Hello, World!

# %%
df = pd.read_csv("../Resources/crop.csv")
print(df.sample(10))
# Out:
#      CciPeriod  IchimokuTenkan  IchimokuKijun  IchimokuSenkou  EntryLevel  \
# 240         50               9             26              52          25
# 124         25               9             26              52          50
# 114         25               9             26              52           0
# 53          15               9             26              52         -50
# 70          15               9             26              52          50
# 139         30               9             26              52           0
# 189         40               9             26              52           0
# 80          20               9             26              52         -25
# 152         35               9             26              52         -50
# 196         40               9             26              52          50
#
#      ExitLevel  Win  Lose WinRate  EstimatedMoney     MDD  ResultPerRisk
# 240          0   74    58  56.06%        94573520  14.65%       645.5859
# ...

# %%
print(df.describe())
# Out:
#         CciPeriod  IchimokuTenkan  IchimokuKijun  IchimokuSenkou  EntryLevel  \
# count  250.000000           250.0          250.0           250.0  250.000000
# mean    27.500000             9.0           26.0            52.0    0.000000
# std     14.390216             0.0            0.0             0.0   35.426263
# min      5.000000             9.0           26.0            52.0  -50.000000
# 25%     15.000000             9.0           26.0            52.0  -25.000000
# 50%     27.500000             9.0           26.0            52.0    0.000000
# 75%     40.000000             9.0           26.0            52.0   25.000000
# max     50.000000             9.0           26.0            52.0   50.000000
#
#         ExitLevel         Win        Lose  EstimatedMoney  ResultPerRisk
# count  250.000000  250.000000  250.000000    2.500000e+02     250.000000
# mean   100.000000  102.328000   72.236000    8.482599e+08    4884.065180
# ...

# %%
cdf = df[['CciPeriod', 'EntryLevel', 'ExitLevel', 'EstimatedMoney']]
print(cdf.sample(10))
# Out:
#      CciPeriod  EntryLevel  ExitLevel  EstimatedMoney
# 164         35           0        200         4728290
# 141         30          25         50        73562262
# 153         35         -50        150         1159938
# 1            5         -50         50       109493155
# 183         40         -25        150         2723588
# 225         50         -50          0         2621327
# 170         35          50          0       606912350
# 74          15          50        200       205801563
# 173         35          50        150        81982127
# 157         35         -25        100         3758213

# %%
viz = cdf[['CciPeriod', 'EntryLevel', 'ExitLevel', 'EstimatedMoney']]
viz.hist()
plt.show()

# %%
plt.scatter(cdf.CciPeriod, cdf.EstimatedMoney,  color='blue')
plt.xlabel("CciPeriod")
plt.ylabel("EstimatedMoney")
plt.show()

# %%
plt.scatter(cdf.EntryLevel, cdf.EstimatedMoney,  color='blue')
plt.xlabel("EntryLevel")
plt.ylabel("EstimatedMoney")
plt.show()

# %%
plt.scatter(cdf.ExitLevel, cdf.EstimatedMoney,  color='blue')
plt.xlabel("ExitLevel")
plt.ylabel("EstimatedMoney")
plt.show()
