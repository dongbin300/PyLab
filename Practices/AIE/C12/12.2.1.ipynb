# %% [markdown]
# In-Context Engineering and Prompt Templates

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

from ibm_watsonx_ai.foundation_models import Model
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watson_machine_learning.foundation_models.extensions.langchain import WatsonxLLM
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       8 from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
#       9 from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
# ---> 10 from ibm_watson_machine_learning.foundation_models.extensions.langchain import WatsonxLLM
#      11 from langchain_core.prompts import PromptTemplate
#      12 from langchain.chains import LLMChain
#
# ModuleNotFoundError: No module named 'ibm_watson_machine_learning'

# %%
def llm_model(prompt_txt, params=None):
    model_id = 'ibm/granite-3-2-8b-instruct'

    default_params = {
        "max_new_tokens": 256,
        "min_new_tokens": 0,
        "temperature": 0.5,
        "top_p": 0.2,
        "top_k": 1
    }

    if params:
        default_params.update(params)

    parameters = {
        GenParams.MAX_NEW_TOKENS: default_params["max_new_tokens"],  # this controls the maximum number of tokens in the generated output
        GenParams.MIN_NEW_TOKENS: default_params["min_new_tokens"], # this controls the minimum number of tokens in the generated output
        GenParams.TEMPERATURE: default_params["temperature"], # this randomness or creativity of the model's responses
        GenParams.TOP_P: default_params["top_p"],
        GenParams.TOP_K: default_params["top_k"]
    }
    
    credentials = {
        "url": "https://us-south.ml.cloud.ibm.com"
    }
    
    project_id = "skills-network"
    
    model = Model(
        model_id=model_id,
        params=parameters,
        credentials=credentials,
        project_id=project_id
    )
    
    mixtral_llm = WatsonxLLM(model=model)
    response  = mixtral_llm.invoke(prompt_txt)
    return response

GenParams().get_example_values()
# Out:
# {'decoding_method': 'sample',
#  'length_penalty': {'decay_factor': 2.5, 'start_index': 5},
#  'temperature': 0.5,
#  'top_p': 0.2,
#  'top_k': 1,
#  'random_seed': 33,
#  'repetition_penalty': 2,
#  'min_new_tokens': 50,
#  'max_new_tokens': 200,
#  'stop_sequences': ['fail'],
#  'time_limit': 600000,
#  'truncate_input_tokens': 200,
#  'prompt_variables': {'object': 'brain'},
#  'return_options': {'input_text': True,
#   'generated_tokens': True,
#   'input_tokens': True,
#   'token_logprobs': True,
#   'token_ranks': False,
#   'top_n_tokens': False}}

# %%
params = {
    "max_new_tokens": 128,
    "min_new_tokens": 10,
    "temperature": 0.5,
    "top_p": 0.2,
    "top_k": 1
}

prompt = "The wind is"

response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[3], line 11
#       1 params = {
#       2     "max_new_tokens": 128,
#       3     "min_new_tokens": 10,
#    (...)      6     "top_k": 1
#       7 }
#       9 prompt = "The wind is"
# ---> 11 response = llm_model(prompt, params)
#      12 print(f"prompt: {prompt}\n")
#      13 print(f"response : {response}\n")
#
# Cell In[2], line 29, in llm_model(prompt_txt, params)
#      23 credentials = {
#      24     "url": "https://us-south.ml.cloud.ibm.com"
#      25 }
#      27 project_id = "skills-network"
# ---> 29 model = Model(
#      30     model_id=model_id,
#      31     params=parameters,
#      32     credentials=credentials,
#      33     project_id=project_id
#      34 )
#      36 mixtral_llm = WatsonxLLM(model=model)
#      37 response  = mixtral_llm.invoke(prompt_txt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\model.py:115, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     108     model_class_deprecated_warning = (
#     109         "The `Model` class is deprecated and will be removed in a future release. "
#     110         "Please use the `ModelInference` class instead. "
#     111         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     112     )
#     113     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 115 ModelInference.__init__(
#     116     self,
#     117     model_id=model_id,
#     118     credentials=credentials,
#     119     params=params,
#     120     project_id=project_id,
#     121     space_id=space_id,
#     122     verify=verify,
#     123     validate=validate,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
prompt = """Classify the following statement as true or false: 
            'The Eiffel Tower is located in Berlin.'

            Answer:
"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[4], line 6
#       1 prompt = """Classify the following statement as true or false:
#       2             'The Eiffel Tower is located in Berlin.'
#       3
#       4             Answer:
#       5 """
# ----> 6 response = llm_model(prompt, params)
#       7 print(f"prompt: {prompt}\n")
#       8 print(f"response : {response}\n")
#
# Cell In[2], line 29, in llm_model(prompt_txt, params)
#      23 credentials = {
#      24     "url": "https://us-south.ml.cloud.ibm.com"
#      25 }
#      27 project_id = "skills-network"
# ---> 29 model = Model(
#      30     model_id=model_id,
#      31     params=parameters,
#      32     credentials=credentials,
#      33     project_id=project_id
#      34 )
#      36 mixtral_llm = WatsonxLLM(model=model)
#      37 response  = mixtral_llm.invoke(prompt_txt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\model.py:115, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     108     model_class_deprecated_warning = (
#     109         "The `Model` class is deprecated and will be removed in a future release. "
#     110         "Please use the `ModelInference` class instead. "
#     111         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     112     )
#     113     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 115 ModelInference.__init__(
#     116     self,
#     117     model_id=model_id,
#     118     credentials=credentials,
#     119     params=params,
#     120     project_id=project_id,
#     121     space_id=space_id,
#     122     verify=verify,
#     123     validate=validate,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
params = {
    "max_new_tokens": 20,
    "temperature": 0.1,
}

prompt = """Here is an example of translating a sentence from English to French:

            English: “How is the weather today?”
            French: “Comment est le temps aujourd'hui?”
            
            Now, translate the following sentence from English to French:
            
            English: “Where is the nearest supermarket?”
            
"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[5], line 16
#       1 params = {
#       2     "max_new_tokens": 20,
#       3     "temperature": 0.1,
#       4 }
#       6 prompt = """Here is an example of translating a sentence from English to French:
#       7
#       8             English: “How is the weather today?”
#    (...)     14
#      15 """
# ---> 16 response = llm_model(prompt, params)
#      17 print(f"prompt: {prompt}\n")
#      18 print(f"response : {response}\n")
#
# Cell In[2], line 29, in llm_model(prompt_txt, params)
#      23 credentials = {
#      24     "url": "https://us-south.ml.cloud.ibm.com"
#      25 }
#      27 project_id = "skills-network"
# ---> 29 model = Model(
#      30     model_id=model_id,
#      31     params=parameters,
#      32     credentials=credentials,
#      33     project_id=project_id
#      34 )
#      36 mixtral_llm = WatsonxLLM(model=model)
#      37 response  = mixtral_llm.invoke(prompt_txt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\model.py:115, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     108     model_class_deprecated_warning = (
#     109         "The `Model` class is deprecated and will be removed in a future release. "
#     110         "Please use the `ModelInference` class instead. "
#     111         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     112     )
#     113     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 115 ModelInference.__init__(
#     116     self,
#     117     model_id=model_id,
#     118     credentials=credentials,
#     119     params=params,
#     120     project_id=project_id,
#     121     space_id=space_id,
#     122     verify=verify,
#     123     validate=validate,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
 #parameters  `max_new_tokens` to 10, which constrains the model to generate brief responses

params = {
    "max_new_tokens": 10,
}

prompt = """Here are few examples of classifying emotions in statements:

            Statement: 'I just won my first marathon!'
            Emotion: Joy
            
            Statement: 'I can't believe I lost my keys again.'
            Emotion: Frustration
            
            Statement: 'My best friend is moving to another country.'
            Emotion: Sadness
            
            Now, classify the emotion in the following statement:
            Statement: 'That movie was so scary I had to cover my eyes.’
            

"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[6], line 23
#       3 params = {
#       4     "max_new_tokens": 10,
#       5 }
#       7 prompt = """Here are few examples of classifying emotions in statements:
#       8
#       9             Statement: 'I just won my first marathon!'
#    (...)     21
#      22 """
# ---> 23 response = llm_model(prompt, params)
#      24 print(f"prompt: {prompt}\n")
#      25 print(f"response : {response}\n")
#
# Cell In[2], line 29, in llm_model(prompt_txt, params)
#      23 credentials = {
#      24     "url": "https://us-south.ml.cloud.ibm.com"
#      25 }
#      27 project_id = "skills-network"
# ---> 29 model = Model(
#      30     model_id=model_id,
#      31     params=parameters,
#      32     credentials=credentials,
#      33     project_id=project_id
#      34 )
#      36 mixtral_llm = WatsonxLLM(model=model)
#      37 response  = mixtral_llm.invoke(prompt_txt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\model.py:115, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     108     model_class_deprecated_warning = (
#     109         "The `Model` class is deprecated and will be removed in a future release. "
#     110         "Please use the `ModelInference` class instead. "
#     111         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     112     )
#     113     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 115 ModelInference.__init__(
#     116     self,
#     117     model_id=model_id,
#     118     credentials=credentials,
#     119     params=params,
#     120     project_id=project_id,
#     121     space_id=space_id,
#     122     verify=verify,
#     123     validate=validate,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
params = {
    "max_new_tokens": 512,
    "temperature": 0.5,
}

prompt = """Consider the problem: 'A store had 22 apples. They sold 15 apples today and got a new delivery of 8 apples. 
            How many apples are there now?’

            Break down each step of your calculation

"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[7], line 12
#       1 params = {
#       2     "max_new_tokens": 512,
#       3     "temperature": 0.5,
#       4 }
#       6 prompt = """Consider the problem: 'A store had 22 apples. They sold 15 apples today and got a new delivery of 8 apples.
#       7             How many apples are there now?’
#       8
#       9             Break down each step of your calculation
#      10
#      11 """
# ---> 12 response = llm_model(prompt, params)
#      13 print(f"prompt: {prompt}\n")
#      14 print(f"response : {response}\n")
#
# Cell In[2], line 29, in llm_model(prompt_txt, params)
#      23 credentials = {
#      24     "url": "https://us-south.ml.cloud.ibm.com"
#      25 }
#      27 project_id = "skills-network"
# ---> 29 model = Model(
#      30     model_id=model_id,
#      31     params=parameters,
#      32     credentials=credentials,
#      33     project_id=project_id
#      34 )
#      36 mixtral_llm = WatsonxLLM(model=model)
#      37 response  = mixtral_llm.invoke(prompt_txt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\model.py:115, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     108     model_class_deprecated_warning = (
#     109         "The `Model` class is deprecated and will be removed in a future release. "
#     110         "Please use the `ModelInference` class instead. "
#     111         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     112     )
#     113     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 115 ModelInference.__init__(
#     116     self,
#     117     model_id=model_id,
#     118     credentials=credentials,
#     119     params=params,
#     120     project_id=project_id,
#     121     space_id=space_id,
#     122     verify=verify,
#     123     validate=validate,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
params = {
    "max_new_tokens": 512,
}

prompt = """When I was 6, my sister was half of my age. Now I am 70, what age is my sister?

            Provide three independent calculations and explanations, then determine the most consistent result.

"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[8], line 10
#       1 params = {
#       2     "max_new_tokens": 512,
#       3 }
#       5 prompt = """When I was 6, my sister was half of my age. Now I am 70, what age is my sister?
#       6
#       7             Provide three independent calculations and explanations, then determine the most consistent result.
#       8
#       9 """
# ---> 10 response = llm_model(prompt, params)
#      11 print(f"prompt: {prompt}\n")
#      12 print(f"response : {response}\n")
#
# Cell In[2], line 29, in llm_model(prompt_txt, params)
#      23 credentials = {
#      24     "url": "https://us-south.ml.cloud.ibm.com"
#      25 }
#      27 project_id = "skills-network"
# ---> 29 model = Model(
#      30     model_id=model_id,
#      31     params=parameters,
#      32     credentials=credentials,
#      33     project_id=project_id
#      34 )
#      36 mixtral_llm = WatsonxLLM(model=model)
#      37 response  = mixtral_llm.invoke(prompt_txt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\model.py:115, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     108     model_class_deprecated_warning = (
#     109         "The `Model` class is deprecated and will be removed in a future release. "
#     110         "Please use the `ModelInference` class instead. "
#     111         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     112     )
#     113     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 115 ModelInference.__init__(
#     116     self,
#     117     model_id=model_id,
#     118     credentials=credentials,
#     119     params=params,
#     120     project_id=project_id,
#     121     space_id=space_id,
#     122     verify=verify,
#     123     validate=validate,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
model_id = 'ibm/granite-3-2-8b-instruct'

parameters = {
    GenParams.MAX_NEW_TOKENS: 256,  # this controls the maximum number of tokens in the generated output
    GenParams.TEMPERATURE: 0.5, # this randomness or creativity of the model's responses
}

credentials = {
    "url": "https://us-south.ml.cloud.ibm.com"
}

project_id = "skills-network"

model = Model(
    model_id=model_id,
    params=parameters,
    credentials=credentials,
    project_id=project_id
)

mixtral_llm = WatsonxLLM(model=model)
mixtral_llm
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[9], line 14
#       8 credentials = {
#       9     "url": "https://us-south.ml.cloud.ibm.com"
#      10 }
#      12 project_id = "skills-network"
# ---> 14 model = Model(
#      15     model_id=model_id,
#      16     params=parameters,
#      17     credentials=credentials,
#      18     project_id=project_id
#      19 )
#      21 mixtral_llm = WatsonxLLM(model=model)
#      22 mixtral_llm
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\model.py:115, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     108     model_class_deprecated_warning = (
#     109         "The `Model` class is deprecated and will be removed in a future release. "
#     110         "Please use the `ModelInference` class instead. "
#     111         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     112     )
#     113     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 115 ModelInference.__init__(
#     116     self,
#     117     model_id=model_id,
#     118     credentials=credentials,
#     119     params=params,
#     120     project_id=project_id,
#     121     space_id=space_id,
#     122     verify=verify,
#     123     validate=validate,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
template = """Tell me a {adjective} joke about {content}.
"""
prompt = PromptTemplate.from_template(template)
prompt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 template = """Tell me a {adjective} joke about {content}.
#       2 """
# ----> 3 prompt = PromptTemplate.from_template(template)
#       4 prompt
#
# NameError: name 'PromptTemplate' is not defined

# %%
prompt.format(adjective="funny", content="chickens")
# Out:
# 'When I was 6, my sister was half of my age. Now I am 70, what age is my sister?\n\n            Provide three independent calculations and explanations, then determine the most consistent result.\n\n'

# %%
llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm)
response = llm_chain.invoke(input = {"adjective": "funny", "content": "chickens"})
print(response["text"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm)
#       2 response = llm_chain.invoke(input = {"adjective": "funny", "content": "chickens"})
#       3 print(response["text"])
#
# NameError: name 'LLMChain' is not defined

# %%
response = llm_chain.invoke(input = {"adjective": "sad", "content": "fish"})
print(response["text"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 response = llm_chain.invoke(input = {"adjective": "sad", "content": "fish"})
#       2 print(response["text"])
#
# NameError: name 'llm_chain' is not defined

# %%
content = """
        The rapid advancement of technology in the 21st century has transformed various industries, including healthcare, education, and transportation. 
        Innovations such as artificial intelligence, machine learning, and the Internet of Things have revolutionized how we approach everyday tasks and complex problems. 
        For instance, AI-powered diagnostic tools are improving the accuracy and speed of medical diagnoses, while smart transportation systems are making cities more efficient and reducing traffic congestion. 
        Moreover, online learning platforms are making education more accessible to people around the world, breaking down geographical and financial barriers. 
        These technological developments are not only enhancing productivity but also contributing to a more interconnected and informed society.
"""

template = """Summarize the {content} in one sentence.
"""
prompt = PromptTemplate.from_template(template)

llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm)
response = llm_chain.invoke(input = {"content": content})
print(response["text"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 11
#       1 content = """
#       2         The rapid advancement of technology in the 21st century has transformed various industries, including healthcare, education, and transportation.
#       3         Innovations such as artificial intelligence, machine learning, and the Internet of Things have revolutionized how we approach everyday tasks and complex problems.
#    (...)      6         These technological developments are not only enhancing productivity but also contributing to a more interconnected and informed society.
#       7 """
#       9 template = """Summarize the {content} in one sentence.
#      10 """
# ---> 11 prompt = PromptTemplate.from_template(template)
#      13 llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm)
#      14 response = llm_chain.invoke(input = {"content": content})
#
# NameError: name 'PromptTemplate' is not defined

# %%
content = """
        The solar system consists of the Sun, eight planets, their moons, dwarf planets, and smaller objects like asteroids and comets. 
        The inner planets—Mercury, Venus, Earth, and Mars—are rocky and solid. 
        The outer planets—Jupiter, Saturn, Uranus, and Neptune—are much larger and gaseous.
"""

question = "Which planets in the solar system are rocky and solid?"

template = """
            Answer the {question} based on the {content}.
            Respond "Unsure about answer" if not sure about the answer.
            
            Answer:
            
"""
prompt = PromptTemplate.from_template(template)
output_key = "answer"

llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
response = llm_chain.invoke(input = {"question":question ,"content": content})
print(response["answer"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 16
#       7 question = "Which planets in the solar system are rocky and solid?"
#       9 template = """
#      10             Answer the {question} based on the {content}.
#      11             Respond "Unsure about answer" if not sure about the answer.
#    (...)     14
#      15 """
# ---> 16 prompt = PromptTemplate.from_template(template)
#      17 output_key = "answer"
#      19 llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
#
# NameError: name 'PromptTemplate' is not defined

# %%
text = """
        The concert last night was an exhilarating experience with outstanding performances by all artists.
"""

categories = "Entertainment, Food and Dining, Technology, Literature, Music."

template = """
            Classify the {text} into one of the {categories}.
            
            Category:
            
"""
prompt = PromptTemplate.from_template(template)
output_key = "category"

llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
response = llm_chain.invoke(input = {"text":text ,"categories": categories})
print(response["category"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 13
#       5 categories = "Entertainment, Food and Dining, Technology, Literature, Music."
#       7 template = """
#       8             Classify the {text} into one of the {categories}.
#       9
#      10             Category:
#      11
#      12 """
# ---> 13 prompt = PromptTemplate.from_template(template)
#      14 output_key = "category"
#      16 llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
#
# NameError: name 'PromptTemplate' is not defined

# %%
description = """
        Retrieve the names and email addresses of all customers from the 'customers' table who have made a purchase in the last 30 days. 
        The table 'purchases' contains a column 'purchase_date'
"""

template = """
            Generate an SQL query based on the {description}
            
            SQL Query:
            
"""
prompt = PromptTemplate.from_template(template)
output_key = "query"

llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
response = llm_chain.invoke(input = {"description":description})
print(response["query"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 12
#       1 description = """
#       2         Retrieve the names and email addresses of all customers from the 'customers' table who have made a purchase in the last 30 days.
#       3         The table 'purchases' contains a column 'purchase_date'
#       4 """
#       6 template = """
#       7             Generate an SQL query based on the {description}
#       8
#       9             SQL Query:
#      10
#      11 """
# ---> 12 prompt = PromptTemplate.from_template(template)
#      13 output_key = "query"
#      15 llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
#
# NameError: name 'PromptTemplate' is not defined

# %%
role = """
        game master
"""

tone = "engaging and immersive"

template = """
            You are an expert {role}. I have this question {question}. I would like our conversation to be {tone}.
            
            Answer:
            
"""
prompt = PromptTemplate.from_template(template)
output_key = "answer"

llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 13
#       5 tone = "engaging and immersive"
#       7 template = """
#       8             You are an expert {role}. I have this question {question}. I would like our conversation to be {tone}.
#       9
#      10             Answer:
#      11
#      12 """
# ---> 13 prompt = PromptTemplate.from_template(template)
#      14 output_key = "answer"
#      16 llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
#
# NameError: name 'PromptTemplate' is not defined

# %%
while True:
    query = input("Question: ")
    
    if query.lower() in ["quit","exit","bye"]:
        print("Answer: Goodbye!")
        break
        
    response = llm_chain.invoke(input = {"role": role, "question": query, "tone": tone})
    
    print("Answer: ", response["answer"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       5     print("Answer: Goodbye!")
#       6     break
# ----> 8 response = llm_chain.invoke(input = {"role": role, "question": query, "tone": tone})
#      10 print("Answer: ", response["answer"])
#
# NameError: name 'llm_chain' is not defined

# %%
params = {
    "max_new_tokens": 128,
    "min_new_tokens": 100,
    "temperature": 1,
    "top_p": 0.1,
    "top_k": 1
}

prompt = "The wind is"

response = llm_model(prompt, params)
print(response)
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[20], line 11
#       1 params = {
#       2     "max_new_tokens": 128,
#       3     "min_new_tokens": 100,
#    (...)      6     "top_k": 1
#       7 }
#       9 prompt = "The wind is"
# ---> 11 response = llm_model(prompt, params)
#      12 print(response)
#
# Cell In[2], line 29, in llm_model(prompt_txt, params)
#      23 credentials = {
#      24     "url": "https://us-south.ml.cloud.ibm.com"
#      25 }
#      27 project_id = "skills-network"
# ---> 29 model = Model(
#      30     model_id=model_id,
#      31     params=parameters,
#      32     credentials=credentials,
#      33     project_id=project_id
#      34 )
#      36 mixtral_llm = WatsonxLLM(model=model)
#      37 response  = mixtral_llm.invoke(prompt_txt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\model.py:115, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     108     model_class_deprecated_warning = (
#     109         "The `Model` class is deprecated and will be removed in a future release. "
#     110         "Please use the `ModelInference` class instead. "
#     111         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     112     )
#     113     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 115 ModelInference.__init__(
#     116     self,
#     117     model_id=model_id,
#     118     credentials=credentials,
#     119     params=params,
#     120     project_id=project_id,
#     121     space_id=space_id,
#     122     verify=verify,
#     123     validate=validate,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
content = """
        The solar system consists of the Sun, eight planets, their moons, dwarf planets, and smaller objects like asteroids and comets. 
        The inner planets—Mercury, Venus, Earth, and Mars—are rocky and solid. 
        The outer planets—Jupiter, Saturn, Uranus, and Neptune—are much larger and gaseous.
"""

question = "Which planets in the solar system are rocky and solid?"

template = """
            Answer the {question} based on the {content}.
            Respond "Unsure about answer" if not sure about the answer.
            
            Answer:
            
"""
prompt = PromptTemplate.from_template(template)
output_key = "answer"

llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key, verbose=True)
response = llm_chain.invoke(input = {"question":question ,"content": content})
print(response["answer"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 16
#       7 question = "Which planets in the solar system are rocky and solid?"
#       9 template = """
#      10             Answer the {question} based on the {content}.
#      11             Respond "Unsure about answer" if not sure about the answer.
#    (...)     14
#      15 """
# ---> 16 prompt = PromptTemplate.from_template(template)
#      17 output_key = "answer"
#      19 llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key, verbose=True)
#
# NameError: name 'PromptTemplate' is not defined

# %%
example_text = """
               Last week's book fair was a delightful gathering of authors and readers, featuring discussions and book signings.
               """

example_category = "Literature"

text = """
       The concert last night was an exhilarating experience with outstanding performances by all artists.
       """

categories = "Entertainment, Food and Dining, Technology, Literature, Music."

template = """
           Example:
           Text: {example_text}
           Category: {example_category}

           Now, classify the following text into one of the specified categories: {categories}
           
           Text: {text}
           
           Category:
           
           """
prompt = PromptTemplate.from_template(template)
output_key = "category"

llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
response = llm_chain.invoke(input = {"example_text": example_text, "example_category":example_category ,"categories": categories, "text":text})
print(response["category"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 25
#      11 categories = "Entertainment, Food and Dining, Technology, Literature, Music."
#      13 template = """
#      14            Example:
#      15            Text: {example_text}
#    (...)     23
#      24            """
# ---> 25 prompt = PromptTemplate.from_template(template)
#      26 output_key = "category"
#      28 llm_chain = LLMChain(prompt=prompt, llm=mixtral_llm, output_key=output_key)
#
# NameError: name 'PromptTemplate' is not defined
