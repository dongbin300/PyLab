# %% [markdown]
# NLP 데이터 로더

# %%
import torchtext
print(torchtext.__version__)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torchtext
#       2 print(torchtext.__version__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchtext\__init__.py:3
#       1 import os
# ----> 3 from torch.hub import _get_torch_home
#       5 # the following import has to happen first in order to load the torchtext C++ library
#       6 from torchtext import _extension  # noqa: F401
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:130
#     128     err = ctypes.WinError(last_error)
#     129     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 130     raise err
#     131 elif res is not None:
#     132     is_loaded = True
#
# OSError: [WinError 127] 지정된 프로시저를 찾을 수 없습니다. Error loading "C:\Users\Gaten\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torchtext.datasets import multi30k, Multi30k
from typing import Iterable, List
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from torchdata.datapipes.iter import IterableWrapper, Mapper
import torchtext

import torch
import torch.nn as nn
import torch.optim as optim

import numpy as np
import random
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 from torch.utils.data import Dataset, DataLoader
#       3 from torchtext.data.utils import get_tokenizer
#       4 from torchtext.vocab import build_vocab_from_iterator
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:130
#     128     err = ctypes.WinError(last_error)
#     129     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 130     raise err
#     131 elif res is not None:
#     132     is_loaded = True
#
# OSError: [WinError 127] 지정된 프로시저를 찾을 수 없습니다. Error loading "C:\Users\Gaten\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
sentences = [
    "If you want to know what a man's like, take a good look at how he treats his inferiors, not his equals.",
    "Fame's a fickle friend, Harry.",
    "It is our choices, Harry, that show what we truly are, far more than our abilities.",
    "Soon we must all face the choice between what is right and what is easy.",
    "Youth can not know how age thinks and feels. But old men are guilty if they forget what it was to be young.",
    "You are awesome!"
]

# Define a custom dataset
class CustomDataset(Dataset):
    def __init__(self, sentences):
        self.sentences = sentences

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        return self.sentences[idx]

# Create an instance of your custom dataset
custom_dataset = CustomDataset(sentences)

# Define batch size
batch_size = 2

# Create a DataLoader
dataloader = DataLoader(custom_dataset, batch_size=batch_size, shuffle=True)

# Iterate through the DataLoader
for batch in dataloader:
    print(batch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       1 sentences = [
#       2     "If you want to know what a man's like, take a good look at how he treats his inferiors, not his equals.",
#       3     "Fame's a fickle friend, Harry.",
#    (...)      7     "You are awesome!"
#       8 ]
#      10 # Define a custom dataset
# ---> 11 class CustomDataset(Dataset):
#      12     def __init__(self, sentences):
#      13         self.sentences = sentences
#
# NameError: name 'Dataset' is not defined

# %%
sentences = [
    "If you want to know what a man's like, take a good look at how he treats his inferiors, not his equals.",
    "Fame's a fickle friend, Harry.",
    "It is our choices, Harry, that show what we truly are, far more than our abilities.",
    "Soon we must all face the choice between what is right and what is easy.",
    "Youth can not know how age thinks and feels. But old men are guilty if they forget what it was to be young.",
    "You are awesome!"
]

# Define a custom data set
class CustomDataset(Dataset):
    def __init__(self, sentences, tokenizer, vocab):
        self.sentences = sentences
        self.tokenizer = tokenizer
        self.vocab = vocab

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        tokens = self.tokenizer(self.sentences[idx])
        # Convert tokens to tensor indices using vocab
        tensor_indices = [self.vocab[token] for token in tokens]
        return torch.tensor(tensor_indices)

# Tokenizer
tokenizer = get_tokenizer("basic_english")

# Build vocabulary
vocab = build_vocab_from_iterator(map(tokenizer, sentences))

# Create an instance of your custom data set
custom_dataset = CustomDataset(sentences, tokenizer, vocab)

print("Custom Dataset Length:", len(custom_dataset))
print("Sample Items:")
for i in range(6):
    sample_item = custom_dataset[i]
    print(f"Item {i + 1}: {sample_item}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       1 sentences = [
#       2     "If you want to know what a man's like, take a good look at how he treats his inferiors, not his equals.",
#       3     "Fame's a fickle friend, Harry.",
#    (...)      7     "You are awesome!"
#       8 ]
#      10 # Define a custom data set
# ---> 11 class CustomDataset(Dataset):
#      12     def __init__(self, sentences, tokenizer, vocab):
#      13         self.sentences = sentences
#
# NameError: name 'Dataset' is not defined

# %%
# Create a custom collate function
def collate_fn(batch):
    # Pad sequences within the batch to have equal lengths
    padded_batch = pad_sequence(batch, batch_first=True, padding_value=0)
    return padded_batch

# %%
# Create a data loader with the custom collate function with batch_first=True,
dataloader = DataLoader(custom_dataset, batch_size=batch_size, collate_fn=collate_fn)

# Iterate through the data loader
for batch in dataloader: 
    for row in batch:
        for idx in row:
            words = [vocab.get_itos()[idx] for idx in row]
        print(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Create a data loader with the custom collate function with batch_first=True,
# ----> 2 dataloader = DataLoader(custom_dataset, batch_size=batch_size, collate_fn=collate_fn)
#       4 # Iterate through the data loader
#       5 for batch in dataloader:
#
# NameError: name 'DataLoader' is not defined

# %%
# Create a custom collate function
def collate_fn_bfFALSE(batch):
    # Pad sequences within the batch to have equal lengths
    padded_batch = pad_sequence(batch, padding_value=0)
    return padded_batch

# %%
# Create a data loader with the custom collate function with batch_first=True,
dataloader_bfFALSE = DataLoader(custom_dataset, batch_size=batch_size, collate_fn=collate_fn_bfFALSE)

# Iterate through the data loader
for seq in dataloader_bfFALSE:
    for row in seq:
        #print(row)
        words = [vocab.get_itos()[idx] for idx in row]
        print(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Create a data loader with the custom collate function with batch_first=True,
# ----> 2 dataloader_bfFALSE = DataLoader(custom_dataset, batch_size=batch_size, collate_fn=collate_fn_bfFALSE)
#       4 # Iterate through the data loader
#       5 for seq in dataloader_bfFALSE:
#
# NameError: name 'DataLoader' is not defined

# %%
# Iterate through the data loader with batch_first = TRUE
for batch in dataloader:    
    print(batch)
    print("Length of sequences in the batch:",batch.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Iterate through the data loader with batch_first = TRUE
# ----> 2 for batch in dataloader:
#       3     print(batch)
#       4     print("Length of sequences in the batch:",batch.shape[1])
#
# NameError: name 'dataloader' is not defined

# %%
# Define a custom data set
class CustomDataset(Dataset):
    def __init__(self, sentences):
        self.sentences = sentences

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        return self.sentences[idx]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Define a custom data set
# ----> 2 class CustomDataset(Dataset):
#       3     def __init__(self, sentences):
#       4         self.sentences = sentences
#
# NameError: name 'Dataset' is not defined

# %%
custom_dataset=CustomDataset(sentences)
custom_dataset[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 custom_dataset=CustomDataset(sentences)
#       2 custom_dataset[0]
#
# NameError: name 'CustomDataset' is not defined

# %%
def collate_fn(batch):
    # Tokenize each sample in the batch using the specified tokenizer
    tensor_batch = []
    for sample in batch:
        tokens = tokenizer(sample)
        # Convert tokens to vocabulary indices and create a tensor for each sample
        tensor_batch.append(torch.tensor([vocab[token] for token in tokens]))

    # Pad sequences within the batch to have equal lengths using pad_sequence
    # batch_first=True ensures that the tensors have shape (batch_size, max_sequence_length)
    padded_batch = pad_sequence(tensor_batch, batch_first=True)
    
    # Return the padded batch
    return padded_batch

# %%
# Create a data loader for the custom dataset
dataloader = DataLoader(
    dataset=custom_dataset,   # Custom PyTorch Dataset containing your data
    batch_size=batch_size,     # Number of samples in each mini-batch
    shuffle=True,              # Shuffle the data at the beginning of each epoch
    collate_fn=collate_fn      # Custom collate function for processing batches
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Create a data loader for the custom dataset
# ----> 2 dataloader = DataLoader(
#       3     dataset=custom_dataset,   # Custom PyTorch Dataset containing your data
#       4     batch_size=batch_size,     # Number of samples in each mini-batch
#       5     shuffle=True,              # Shuffle the data at the beginning of each epoch
#       6     collate_fn=collate_fn      # Custom collate function for processing batches
#       7 )
#
# NameError: name 'DataLoader' is not defined

# %%
for batch in dataloader:
    print(batch)
    print("shape of sample",len(batch))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for batch in dataloader:
#       2     print(batch)
#       3     print("shape of sample",len(batch))
#
# NameError: name 'dataloader' is not defined

# %%
corpus = [
    "Ceci est une phrase.",
    "C'est un autre exemple de phrase.",
    "Voici une troisième phrase.",
    "Il fait beau aujourd'hui.",
    "J'aime beaucoup la cuisine française.",
    "Quel est ton plat préféré ?",
    "Je t'adore.",
    "Bon appétit !",
    "Je suis en train d'apprendre le français.",
    "Nous devons partir tôt demain matin.",
    "Je suis heureux.",
    "Le film était vraiment captivant !",
    "Je suis là.",
    "Je ne sais pas.",
    "Je suis fatigué après une longue journée de travail.",
    "Est-ce que tu as des projets pour le week-end ?",
    "Je vais chez le médecin cet après-midi.",
    "La musique adoucit les mœurs.",
    "Je dois acheter du pain et du lait.",
    "Il y a beaucoup de monde dans cette ville.",
    "Merci beaucoup !",
    "Au revoir !",
    "Je suis ravi de vous rencontrer enfin !",
    "Les vacances sont toujours trop courtes.",
    "Je suis en retard.",
    "Félicitations pour ton nouveau travail !",
    "Je suis désolé, je ne peux pas venir à la réunion.",
    "À quelle heure est le prochain train ?",
    "Bonjour !",
    "C'est génial !"
]
for batch in dataloader:
    print(batch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 33
#       1 corpus = [
#       2     "Ceci est une phrase.",
#       3     "C'est un autre exemple de phrase.",
#    (...)     31     "C'est génial !"
#      32 ]
# ---> 33 for batch in dataloader:
#      34     print(batch)
#
# NameError: name 'dataloader' is not defined

# %%
# You would modify the URLs for the data set since the links to the original data set are broken

multi30k.URL["train"] = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-AI0205EN-SkillsNetwork/training.tar.gz"
multi30k.URL["valid"] = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-AI0205EN-SkillsNetwork/validation.tar.gz"

SRC_LANGUAGE = 'de'
TGT_LANGUAGE = 'en'

train_iter = Multi30k(split='train', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # You would modify the URLs for the data set since the links to the original data set are broken
# ----> 3 multi30k.URL["train"] = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-AI0205EN-SkillsNetwork/training.tar.gz"
#       4 multi30k.URL["valid"] = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-AI0205EN-SkillsNetwork/validation.tar.gz"
#       6 SRC_LANGUAGE = 'de'
#
# NameError: name 'multi30k' is not defined

# %%
data_set = iter(train_iter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data_set = iter(train_iter)
#
# NameError: name 'train_iter' is not defined

# %%
for n in range(5):
    # Getting the next pair of source and target sentences from the training data set
    src, tgt = next(data_set)

    # Printing the source (German) and target (English) sentences
    print(f"sample {str(n+1)}")
    print(f"Source ({SRC_LANGUAGE}): {src}\nTarget ({TGT_LANGUAGE}): {tgt}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 for n in range(5):
#       2     # Getting the next pair of source and target sentences from the training data set
# ----> 3     src, tgt = next(data_set)
#       5     # Printing the source (German) and target (English) sentences
#       6     print(f"sample {str(n+1)}")
#
# NameError: name 'data_set' is not defined

# %%
german, english = next(data_set)
print(f"Source German ({SRC_LANGUAGE}): {german}\nTarget English  ({TGT_LANGUAGE}): { english }")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 german, english = next(data_set)
#       2 print(f"Source German ({SRC_LANGUAGE}): {german}\nTarget English  ({TGT_LANGUAGE}): { english }")
#
# NameError: name 'data_set' is not defined

# %%
from torchtext.data.utils import get_tokenizer

# Making a placeholder dict to store both tokenizers
token_transform = {}

token_transform[SRC_LANGUAGE] = get_tokenizer('spacy', language='de_core_news_sm')
token_transform[TGT_LANGUAGE] = get_tokenizer('spacy', language='en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from torchtext.data.utils import get_tokenizer
#       3 # Making a placeholder dict to store both tokenizers
#       4 token_transform = {}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchtext\__init__.py:3
#       1 import os
# ----> 3 from torch.hub import _get_torch_home
#       5 # the following import has to happen first in order to load the torchtext C++ library
#       6 from torchtext import _extension  # noqa: F401
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:130
#     128     err = ctypes.WinError(last_error)
#     129     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 130     raise err
#     131 elif res is not None:
#     132     is_loaded = True
#
# OSError: [WinError 127] 지정된 프로시저를 찾을 수 없습니다. Error loading "C:\Users\Gaten\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
token_transform['de'](german)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 token_transform['de'](german)
#
# NameError: name 'token_transform' is not defined

# %%
token_transform['en'](english)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 token_transform['en'](english)
#
# NameError: name 'token_transform' is not defined

# %%
# Define special symbols and indices
UNK_IDX, PAD_IDX, BOS_IDX, EOS_IDX = 0, 1, 2, 3
# Make sure the tokens are in order of their indices to properly insert them in vocab
special_symbols = ['<unk>', '<pad>', '<bos>', '<eos>']

# %%
#place holder dict for 'en' and 'de' vocab transforms
vocab_transform = {}

# %%
def yield_tokens(data_iter: Iterable, language: str) -> List[str]:
    # Define a mapping to associate the source and target languages
    # with their respective positions in the data samples.
    language_index = {SRC_LANGUAGE: 0, TGT_LANGUAGE: 1}

    # Iterate over each data sample in the provided dataset iterator
    for data_sample in data_iter:
        # Tokenize the data sample corresponding to the specified language
        # and yield the resulting tokens.
        yield token_transform[language](data_sample[language_index[language]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 def yield_tokens(data_iter: Iterable, language: str) -> List[str]:
#       2     # Define a mapping to associate the source and target languages
#       3     # with their respective positions in the data samples.
#       4     language_index = {SRC_LANGUAGE: 0, TGT_LANGUAGE: 1}
#       6     # Iterate over each data sample in the provided dataset iterator
#
# NameError: name 'Iterable' is not defined

# %%
for ln in [SRC_LANGUAGE, TGT_LANGUAGE]:
    # Training data iterator
    train_iterator = Multi30k(split='train', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
    #To decrease the number of padding tokens, you sort data on the source length to batch similar-length sequences together
    sorted_dataset = sorted(train_iterator, key=lambda x: len(x[0].split()))
    # Create torchtext's Vocab object
    vocab_transform[ln] = build_vocab_from_iterator(yield_tokens(sorted_dataset, ln),
                                                    min_freq=1,
                                                    specials=special_symbols,
                                                    special_first=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 for ln in [SRC_LANGUAGE, TGT_LANGUAGE]:
#       2     # Training data iterator
#       3     train_iterator = Multi30k(split='train', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
#       4     #To decrease the number of padding tokens, you sort data on the source length to batch similar-length sequences together
#
# NameError: name 'SRC_LANGUAGE' is not defined

# %%
# If not set, it throws ``RuntimeError`` when the queried token is not found in the Vocabulary.
for ln in [SRC_LANGUAGE, TGT_LANGUAGE]:
  vocab_transform[ln].set_default_index(UNK_IDX)

seq_en=vocab_transform['en'](token_transform['en'](english))
print(f"English text string: {english}\n English sequence: {seq_en}")

seq_de=vocab_transform['de'](token_transform['de'](german))
print(f"German text string: {german}\n German sequence: {seq_de}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # If not set, it throws ``RuntimeError`` when the queried token is not found in the Vocabulary.
# ----> 2 for ln in [SRC_LANGUAGE, TGT_LANGUAGE]:
#       3   vocab_transform[ln].set_default_index(UNK_IDX)
#       5 seq_en=vocab_transform['en'](token_transform['en'](english))
#
# NameError: name 'SRC_LANGUAGE' is not defined

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# function to add BOS/EOS, flip source sentence and create tensor for input sequence indices
def tensor_transform_s(token_ids: List[int]):
    return torch.cat((torch.tensor([BOS_IDX]),
                      torch.flip(torch.tensor(token_ids), dims=(0,)),
                      torch.tensor([EOS_IDX])))

# function to add BOS/EOS and create tensor for input sequence indices
def tensor_transform_t(token_ids: List[int]):
    return torch.cat((torch.tensor([BOS_IDX]),
                      torch.tensor(token_ids),
                      torch.tensor([EOS_IDX])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#       3 # function to add BOS/EOS, flip source sentence and create tensor for input sequence indices
#       4 def tensor_transform_s(token_ids: List[int]):
#
# NameError: name 'torch' is not defined

# %%
seq_en=tensor_transform_s(seq_en)
seq_en
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 seq_en=tensor_transform_s(seq_en)
#       2 seq_en
#
# NameError: name 'tensor_transform_s' is not defined

# %%
seq_de=tensor_transform_t(seq_de)
seq_de
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 seq_de=tensor_transform_t(seq_de)
#       2 seq_de
#
# NameError: name 'tensor_transform_t' is not defined

# %%
# helper function to club together sequential operations
def sequential_transforms(*transforms):
    def func(txt_input):
        for transform in transforms:
            txt_input = transform(txt_input)
        return txt_input
    return func

# ``src`` and ``tgt`` language text transforms to convert raw strings into tensors indices
text_transform = {}

text_transform[SRC_LANGUAGE] = sequential_transforms(token_transform[SRC_LANGUAGE], #Tokenization
                                            vocab_transform[SRC_LANGUAGE], #Numericalization
                                            tensor_transform_s) # Add BOS/EOS and create tensor

text_transform[TGT_LANGUAGE] = sequential_transforms(token_transform[TGT_LANGUAGE], #Tokenization
                                            vocab_transform[TGT_LANGUAGE], #Numericalization
                                            tensor_transform_t) # Add BOS/EOS and create tensor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 12
#       9 # ``src`` and ``tgt`` language text transforms to convert raw strings into tensors indices
#      10 text_transform = {}
# ---> 12 text_transform[SRC_LANGUAGE] = sequential_transforms(token_transform[SRC_LANGUAGE], #Tokenization
#      13                                             vocab_transform[SRC_LANGUAGE], #Numericalization
#      14                                             tensor_transform_s) # Add BOS/EOS and create tensor
#      16 text_transform[TGT_LANGUAGE] = sequential_transforms(token_transform[TGT_LANGUAGE], #Tokenization
#      17                                             vocab_transform[TGT_LANGUAGE], #Numericalization
#      18                                             tensor_transform_t) # Add BOS/EOS and create tensor
#
# NameError: name 'token_transform' is not defined

# %%
# function to collate data samples into batch tensors
def collate_fn(batch):
    src_batch, tgt_batch = [], []
    for src_sample, tgt_sample in batch:
        src_sequences = text_transform[SRC_LANGUAGE](src_sample.rstrip("\n"))
        src_sequences = torch.tensor(src_sequences, dtype=torch.int64)
        tgt_sequences = text_transform[TGT_LANGUAGE](tgt_sample.rstrip("\n"))
        tgt_sequences = torch.tensor(tgt_sequences, dtype=torch.int64)
        src_batch.append(src_sequences)
        tgt_batch.append(tgt_sequences)

    src_batch = pad_sequence(src_batch, padding_value=PAD_IDX,batch_first=True)
    tgt_batch = pad_sequence(tgt_batch, padding_value=PAD_IDX,batch_first=True)
    
    return src_batch.to(device), tgt_batch.to(device)

# %%
BATCH_SIZE = 4

train_iterator = Multi30k(split='train', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
sorted_train_iterator = sorted(train_iterator, key=lambda x: len(x[0].split()))
train_dataloader = DataLoader(sorted_train_iterator, batch_size=BATCH_SIZE, collate_fn=collate_fn,drop_last=True)

valid_iterator = Multi30k(split='valid', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
sorted_valid_dataloader = sorted(valid_iterator, key=lambda x: len(x[0].split()))
valid_dataloader = DataLoader(sorted_valid_dataloader, batch_size=BATCH_SIZE, collate_fn=collate_fn,drop_last=True)


src, trg = next(iter(train_dataloader))
src,trg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 BATCH_SIZE = 4
# ----> 3 train_iterator = Multi30k(split='train', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
#       4 sorted_train_iterator = sorted(train_iterator, key=lambda x: len(x[0].split()))
#       5 train_dataloader = DataLoader(sorted_train_iterator, batch_size=BATCH_SIZE, collate_fn=collate_fn,drop_last=True)
#
# NameError: name 'Multi30k' is not defined
