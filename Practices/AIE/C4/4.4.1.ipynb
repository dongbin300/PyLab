# %% [markdown]
# PyTorch 다중 선형 회귀

# %%
from torch import nn
import torch
torch.manual_seed(1)

# %%
# w = [[2], [3]], b = [[1]]
w = torch.tensor([[2.0], [3.0]], requires_grad=True)
b = torch.tensor([[1.0]], requires_grad=True)

# y = xw + b
def forward(x):
    yhat = torch.mm(x, w) + b
    return yhat

# %%
# x = [[1, 2]]
# y = 1*2 + 2*3 + 1 = 9
x = torch.tensor([[1.0, 2.0]])
yhat = forward(x)
print("The result: ", yhat)
# Out:
# The result:  tensor([[9.]], grad_fn=<AddBackward0>)

# %%
# X = [[1, 1], [1, 2], [1, 3]]
X = torch.tensor([[1.0, 1.0], [1.0, 2.0], [1.0, 3.0]])
# y = Xw + b
# [2+3+1, 2+6+1, 2+9+1] = [6, 9, 12]
yhat = forward(X)
print("The result: ", yhat)
# Out:
# The result:  tensor([[ 6.],
#         [ 9.],
#         [12.]], grad_fn=<AddBackward0>)

# %%
# 2D입력, 1D출력 (y = w1x1 + w2x2 + b)
# nn.Linear로 생성시 weight와 bias는 자동 랜덤 설정됨
model = nn.Linear(2, 1)
print(("weight: ", model.weight.data))
print(("bias: ", model.bias.data))
# y = 1*w1 + 2*w2 + b
yhat = model(x)
print("The result: ", yhat)
# Out:
# ('weight: ', tensor([[0.1975, 0.6707]]))
# ('bias: ', tensor([0.4667]))
# The result:  tensor([[2.0057]], grad_fn=<AddmmBackward0>)

# %%
yhat = model(X)
print("The result: ", yhat)
# Out:
# The result:  tensor([[1.3350],
#         [2.0057],
#         [2.6765]], grad_fn=<AddmmBackward0>)

# %%
# 선형 회귀 클래스 구현
class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %%
model = linear_regression(2, 1)
print("The parameters: ", list(model.parameters()))
print("The parameters: ", model.state_dict())
# Out:
# The parameters:  [Parameter containing:
# tensor([[ 0.6209, -0.1178]], requires_grad=True), Parameter containing:
# tensor([0.3026], requires_grad=True)]
# The parameters:  OrderedDict({'linear.weight': tensor([[ 0.6209, -0.1178]]), 'linear.bias': tensor([0.3026])})

# %%
yhat = model(x)
print("The result: ", yhat)
# Out:
# The result:  tensor([[0.6880]], grad_fn=<AddmmBackward0>)

# %%
yhat = model(X)
print("The result: ", yhat)
# Out:
# The result:  tensor([[0.8057],
#         [0.6880],
#         [0.5702]], grad_fn=<AddmmBackward0>)
