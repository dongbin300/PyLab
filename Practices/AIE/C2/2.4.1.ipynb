# %% [markdown]
# Keras를 사용한 CNN

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.utils import to_categorical

from keras.layers import Conv2D # to add convolutional layers
from keras.layers import MaxPooling2D # to add pooling layers
from keras.layers import Flatten # to flatten data for fully connected layers

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 5s - 17ms/step - accuracy: 0.9159 - loss: 0.2944 - val_accuracy: 0.9652 - val_loss: 0.1124
# Epoch 2/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9717 - loss: 0.0979 - val_accuracy: 0.9770 - val_loss: 0.0753
# Epoch 3/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9804 - loss: 0.0677 - val_accuracy: 0.9825 - val_loss: 0.0588
# Epoch 4/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9847 - loss: 0.0516 - val_accuracy: 0.9837 - val_loss: 0.0530
# Epoch 5/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9875 - loss: 0.0417 - val_accuracy: 0.9844 - val_loss: 0.0438
# Epoch 6/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9898 - loss: 0.0346 - val_accuracy: 0.9871 - val_loss: 0.0403
# Epoch 7/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9912 - loss: 0.0280 - val_accuracy: 0.9872 - val_loss: 0.0415
# Epoch 8/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9931 - loss: 0.0232 - val_accuracy: 0.9860 - val_loss: 0.0437
# Epoch 9/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9943 - loss: 0.0188 - val_accuracy: 0.9872 - val_loss: 0.0368
# Epoch 10/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9952 - loss: 0.0160 - val_accuracy: 0.9872 - val_loss: 0.0408
# Accuracy: 0.9872000217437744
#  Error: 1.2799978256225586

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 5s - 18ms/step - accuracy: 0.8658 - loss: 0.4719 - val_accuracy: 0.9526 - val_loss: 0.1637
# Epoch 2/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9603 - loss: 0.1360 - val_accuracy: 0.9698 - val_loss: 0.0978
# Epoch 3/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9716 - loss: 0.0942 - val_accuracy: 0.9761 - val_loss: 0.0780
# Epoch 4/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9779 - loss: 0.0743 - val_accuracy: 0.9809 - val_loss: 0.0631
# Epoch 5/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9816 - loss: 0.0621 - val_accuracy: 0.9831 - val_loss: 0.0529
# Epoch 6/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9841 - loss: 0.0539 - val_accuracy: 0.9841 - val_loss: 0.0516
# Epoch 7/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9854 - loss: 0.0487 - val_accuracy: 0.9828 - val_loss: 0.0539
# Epoch 8/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9876 - loss: 0.0423 - val_accuracy: 0.9866 - val_loss: 0.0419
# Epoch 9/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9877 - loss: 0.0396 - val_accuracy: 0.9847 - val_loss: 0.0467
# Epoch 10/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9893 - loss: 0.0354 - val_accuracy: 0.9864 - val_loss: 0.0431
# Accuracy: 0.9864000082015991
#  Error: 1.359999179840088

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 4s - 71ms/step - accuracy: 0.6636 - loss: 1.2969 - val_accuracy: 0.8784 - val_loss: 0.4245
# Epoch 2/10
# 59/59 - 4s - 62ms/step - accuracy: 0.8972 - loss: 0.3506 - val_accuracy: 0.9240 - val_loss: 0.2646
# Epoch 3/10
# 59/59 - 4s - 60ms/step - accuracy: 0.9283 - loss: 0.2420 - val_accuracy: 0.9462 - val_loss: 0.1838
# Epoch 4/10
# 59/59 - 4s - 60ms/step - accuracy: 0.9482 - loss: 0.1768 - val_accuracy: 0.9581 - val_loss: 0.1389
# Epoch 5/10
# 59/59 - 4s - 60ms/step - accuracy: 0.9589 - loss: 0.1385 - val_accuracy: 0.9669 - val_loss: 0.1136
# Epoch 6/10
# 59/59 - 3s - 59ms/step - accuracy: 0.9664 - loss: 0.1149 - val_accuracy: 0.9732 - val_loss: 0.0919
# Epoch 7/10
# 59/59 - 4s - 60ms/step - accuracy: 0.9704 - loss: 0.0988 - val_accuracy: 0.9761 - val_loss: 0.0825
# Epoch 8/10
# 59/59 - 4s - 60ms/step - accuracy: 0.9736 - loss: 0.0891 - val_accuracy: 0.9782 - val_loss: 0.0763
# Epoch 9/10
# 59/59 - 4s - 60ms/step - accuracy: 0.9754 - loss: 0.0810 - val_accuracy: 0.9820 - val_loss: 0.0672
# Epoch 10/10
# 59/59 - 4s - 60ms/step - accuracy: 0.9778 - loss: 0.0731 - val_accuracy: 0.9822 - val_loss: 0.0620
# Accuracy: 0.982200026512146
#  Error: 1.7799973487854004

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 4s - 72ms/step - accuracy: 0.6763 - loss: 1.3186 - val_accuracy: 0.8765 - val_loss: 0.4143
# Epoch 2/25
# 59/59 - 4s - 62ms/step - accuracy: 0.9051 - loss: 0.3179 - val_accuracy: 0.9321 - val_loss: 0.2332
# Epoch 3/25
# 59/59 - 4s - 62ms/step - accuracy: 0.9383 - loss: 0.2073 - val_accuracy: 0.9537 - val_loss: 0.1549
# Epoch 4/25
# 59/59 - 4s - 62ms/step - accuracy: 0.9545 - loss: 0.1534 - val_accuracy: 0.9644 - val_loss: 0.1181
# Epoch 5/25
# 59/59 - 4s - 64ms/step - accuracy: 0.9637 - loss: 0.1223 - val_accuracy: 0.9711 - val_loss: 0.0972
# Epoch 6/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9694 - loss: 0.1033 - val_accuracy: 0.9748 - val_loss: 0.0854
# Epoch 7/25
# 59/59 - 4s - 62ms/step - accuracy: 0.9729 - loss: 0.0906 - val_accuracy: 0.9774 - val_loss: 0.0747
# Epoch 8/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9757 - loss: 0.0813 - val_accuracy: 0.9791 - val_loss: 0.0710
# Epoch 9/25
# 59/59 - 4s - 60ms/step - accuracy: 0.9782 - loss: 0.0737 - val_accuracy: 0.9808 - val_loss: 0.0628
# Epoch 10/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9798 - loss: 0.0669 - val_accuracy: 0.9813 - val_loss: 0.0606
# Epoch 11/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9814 - loss: 0.0621 - val_accuracy: 0.9826 - val_loss: 0.0578
# Epoch 12/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9820 - loss: 0.0594 - val_accuracy: 0.9837 - val_loss: 0.0538
# Epoch 13/25
# 59/59 - 4s - 60ms/step - accuracy: 0.9837 - loss: 0.0544 - val_accuracy: 0.9844 - val_loss: 0.0504
# Epoch 14/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9844 - loss: 0.0512 - val_accuracy: 0.9837 - val_loss: 0.0499
# Epoch 15/25
# 59/59 - 4s - 60ms/step - accuracy: 0.9854 - loss: 0.0478 - val_accuracy: 0.9852 - val_loss: 0.0474
# Epoch 16/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9864 - loss: 0.0451 - val_accuracy: 0.9837 - val_loss: 0.0505
# Epoch 17/25
# 59/59 - 4s - 60ms/step - accuracy: 0.9870 - loss: 0.0435 - val_accuracy: 0.9849 - val_loss: 0.0469
# Epoch 18/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9878 - loss: 0.0407 - val_accuracy: 0.9846 - val_loss: 0.0480
# Epoch 19/25
# 59/59 - 4s - 60ms/step - accuracy: 0.9881 - loss: 0.0404 - val_accuracy: 0.9856 - val_loss: 0.0470
# Epoch 20/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9881 - loss: 0.0396 - val_accuracy: 0.9848 - val_loss: 0.0465
# Epoch 21/25
# 59/59 - 4s - 62ms/step - accuracy: 0.9891 - loss: 0.0367 - val_accuracy: 0.9859 - val_loss: 0.0438
# Epoch 22/25
# 59/59 - 4s - 62ms/step - accuracy: 0.9895 - loss: 0.0350 - val_accuracy: 0.9862 - val_loss: 0.0428
# Epoch 23/25
# 59/59 - 4s - 61ms/step - accuracy: 0.9899 - loss: 0.0336 - val_accuracy: 0.9869 - val_loss: 0.0413
# Epoch 24/25
# 59/59 - 4s - 62ms/step - accuracy: 0.9901 - loss: 0.0329 - val_accuracy: 0.9859 - val_loss: 0.0429
# Epoch 25/25
# 59/59 - 4s - 62ms/step - accuracy: 0.9907 - loss: 0.0314 - val_accuracy: 0.9870 - val_loss: 0.0400
# Accuracy: 0.9869999885559082
#  Error: 1.3000011444091797
