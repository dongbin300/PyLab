# %% [markdown]
# # **Put Whole Document into Prompt and Ask the Model**

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_community.document_loaders import TextLoader
from langchain_ibm import WatsonxLLM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 10
#       8 from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
#       9 from langchain_core.prompts import PromptTemplate
# ---> 10 from langchain.chains import LLMChain
#      11 from langchain_community.document_loaders import TextLoader
#      12 from langchain_ibm import WatsonxLLM
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
def llm_model(model_id):
    parameters = {
        GenParams.MAX_NEW_TOKENS: 256,  # this controls the maximum number of tokens in the generated output
        GenParams.TEMPERATURE: 0.5, # this randomness or creativity of the model's responses
    }
    
    credentials = {
        "url": "https://us-south.ml.cloud.ibm.com"
    }
    
    project_id = "skills-network"
    
    model = ModelInference(
        model_id=model_id,
        params=parameters,
        credentials=credentials,
        project_id=project_id
    )
    
    llm = WatsonxLLM(watsonx_model = model)
    return llm

# %%
llama_llm = llm_model('meta-llama/llama-3-405b-instruct')
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 llama_llm = llm_model('meta-llama/llama-3-405b-instruct')
#
# Cell In[3], line 13, in llm_model(model_id)
#       7 credentials = {
#       8     "url": "https://us-south.ml.cloud.ibm.com"
#       9 }
#      11 project_id = "skills-network"
# ---> 13 model = ModelInference(
#      14     model_id=model_id,
#      15     params=parameters,
#      16     credentials=credentials,
#      17     project_id=project_id
#      18 )
#      20 llm = WatsonxLLM(watsonx_model = model)
#      21 return llm
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
llama_llm.invoke("How are you?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llama_llm.invoke("How are you?")
#
# NameError: name 'llama_llm' is not defined

# %%
#!wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/d_ahNwb1L2duIxBR6RD63Q/state-of-the-union.txt"

# %%
loader = TextLoader("state-of-the-union.txt")
data = loader.load()

content = data[0].page_content
content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 loader = TextLoader("state-of-the-union.txt")
#       2 data = loader.load()
#       4 content = data[0].page_content
#
# NameError: name 'TextLoader' is not defined

# %%
template = """According to the document content here 
            {content},
            answer this question 
            {question}.
            Do not try to make up the answer.
                
            YOUR RESPONSE:
"""

prompt_template = PromptTemplate(template=template, input_variables=['content', 'question'])
prompt_template
# Out:
# PromptTemplate(input_variables=['content', 'question'], input_types={}, partial_variables={}, template='According to the document content here \n            {content},\n            answer this question \n            {question}.\n            Do not try to make up the answer.\n\n            YOUR RESPONSE:\n')

# %%
mixtral_llm = llm_model('mistralai/mistral-small-3-1-24b-instruct-2503')
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 mixtral_llm = llm_model('mistralai/mistral-small-3-1-24b-instruct-2503')
#
# Cell In[3], line 13, in llm_model(model_id)
#       7 credentials = {
#       8     "url": "https://us-south.ml.cloud.ibm.com"
#       9 }
#      11 project_id = "skills-network"
# ---> 13 model = ModelInference(
#      14     model_id=model_id,
#      15     params=parameters,
#      16     credentials=credentials,
#      17     project_id=project_id
#      18 )
#      20 llm = WatsonxLLM(watsonx_model = model)
#      21 return llm
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
query_chain = LLMChain(llm=mixtral_llm, prompt=prompt_template)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 query_chain = LLMChain(llm=mixtral_llm, prompt=prompt_template)
#
# NameError: name 'LLMChain' is not defined

# %%
query = "It is in which year of our nation?"
response = query_chain.invoke(input={'content': content, 'question': query})
print(response['text'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 query = "It is in which year of our nation?"
# ----> 2 response = query_chain.invoke(input={'content': content, 'question': query})
#       3 print(response['text'])
#
# NameError: name 'query_chain' is not defined

# %%
query_chain = LLMChain(llm=llama_llm, prompt=prompt_template)
query_chain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 query_chain = LLMChain(llm=llama_llm, prompt=prompt_template)
#       2 query_chain
#
# NameError: name 'LLMChain' is not defined

# %%
query = "It is in which year of our nation?"
response = query_chain.invoke(input={'content': content, 'question': query})
print(response['text'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 query = "It is in which year of our nation?"
# ----> 2 response = query_chain.invoke(input={'content': content, 'question': query})
#       3 print(response['text'])
#
# NameError: name 'query_chain' is not defined

# %%
granite_llm = llm_model('ibm/granite-3-8b-instruct')
query_chain = LLMChain(llm=granite_llm, prompt=prompt_template)
query = "It is in which year of our nation?"
response = query_chain.invoke(input={'content': content, 'question': query})
print(response['text'])
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 granite_llm = llm_model('ibm/granite-3-8b-instruct')
#       2 query_chain = LLMChain(llm=granite_llm, prompt=prompt_template)
#       3 query = "It is in which year of our nation?"
#
# Cell In[3], line 13, in llm_model(model_id)
#       7 credentials = {
#       8     "url": "https://us-south.ml.cloud.ibm.com"
#       9 }
#      11 project_id = "skills-network"
# ---> 13 model = ModelInference(
#      14     model_id=model_id,
#      15     params=parameters,
#      16     credentials=credentials,
#      17     project_id=project_id
#      18 )
#      20 llm = WatsonxLLM(watsonx_model = model)
#      21 return llm
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:199, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, max_retries, delay_time, retry_status_codes, **kwargs)
#     196 if credentials:
#     197     from ibm_watsonx_ai import APIClient
# --> 199     self.set_api_client(APIClient(credentials, verify=verify))
#     200 elif api_client:
#     201     self.set_api_client(api_client)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ibm_watsonx_ai\client.py:397, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     392         raise WMLClientError(
#     393             Messages.get_message(message_id="invalid_url_provided")
#     394         )
#     396     if not self._is_IAM():
# --> 397         raise WMLClientError(
#     398             Messages.get_message(message_id="apikey_not_provided")
#     399         )
#     400 else:
#     401     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'
